# %%
import yaml


data = {
    'train': '../PoongsanData/full_Data',  
    'val': '../PoongsanData/full_Data',  
    'test': '../PoongsanData/test', 
    'nc': 1,
    'names': ['tank']
}

with open('yaml/FULL.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
# !python train.py --device 0 --batch-size 64 --img 416 416 --data ./yaml/FULL.yaml --cfg cfg/yolov4-tiny.cfg --weights '' --name FULL --epochs 500
# Out:
# WARNING: --img-size 416 must be multiple of max stride 64, updating to 448
# Using torch 2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MB)
#
# Namespace(weights="''", cfg='cfg/yolov4-tiny.cfg', data='./yaml/FULL.yaml', hyp='data/hyp.scratch.yaml', epochs=500, batch_size=64, img_size=[416, 416], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, log_imgs=16, workers=8, project='runs/train', name='FULL', exist_ok=False, total_batch_size=64, world_size=1, global_rank=-1, save_dir='runs\\train\\FULL')
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
import yaml


data = {
    'train': '../PoongsanData/full_Data',  
    'val': '../PoongsanData/test_data_v2',  
    'test': '../PoongsanData/test_data_v2', 
    'nc': 1,
    'names': ['tank']
}

with open('yaml/FULL.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
# !python test.py --batch-size 16 --img 416 --data ./yaml/FULL.yaml --cfg cfg/yolov4-tiny.cfg --weights "runs\train\FULL\weights\last.pt" --name FULL_last --names data/data.names
# Out:
# Namespace(weights=['runs\\train\\FULL\\weights\\last.pt'], data='./yaml/FULL.yaml', batch_size=16, img_size=416, conf_thres=0.001, iou_thres=0.65, task='val', device='', single_cls=False, augment=False, verbose=False, save_txt=False, save_conf=False, save_json=False, project='runs/test', name='FULL_last', exist_ok=False, cfg='cfg/yolov4-tiny.cfg', names='data/data.names')
# WARNING: --img-size 416 must be multiple of max stride 64, updating to 448
#                  all          50         111       0.598       0.333       0.449       0.161
# Speed: 7.0/1.4/8.4 ms inference/NMS/total per 448x448 image at batch-size 16
# Results saved to runs\test\FULL_last
# Using torch 2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MB)
#
# Model Summary: 99 layers, 5874116 parameters, 5874116 gradients
# ...
